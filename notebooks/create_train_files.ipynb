# %%
import pandas as pd
import numpy as np

# %%
ctrp1_auc = pd.read_csv("../data/CTRP/ctrp1_auc.tab", sep="\t")[['ccle_name', 'isomeric_smiles', 'auc']]
ctrp2_auc = pd.read_csv("../data/CTRP/ctrp2_auc.tab", sep="\t")[['ccle_name', 'isomeric_smiles', 'auc']]

gdsc1_auc = pd.read_csv("../data/GDSC/gdsc1_auc.tab", sep="\t")[['ccle_name', 'isomeric_smiles', 'auc']]
gdsc2_auc = pd.read_csv("../data/GDSC/gdsc2_auc.tab", sep="\t")[['ccle_name', 'isomeric_smiles', 'auc']]

# %%
drugcell_all_cg = ctrp1_auc.query()
# Out:
#                           ccle_name  \
# 0                         U2OS_BONE
# 1                       MCF7_BREAST
# 2       GAMG_CENTRAL_NERVOUS_SYSTEM
# 3      LN229_CENTRAL_NERVOUS_SYSTEM
# 4      SF295_CENTRAL_NERVOUS_SYSTEM
# ...                             ...
# 59640            5637_URINARY_TRACT
# 59641          HT1376_URINARY_TRACT
# 59642           KMBC2_URINARY_TRACT
# 59643             RT4_URINARY_TRACT
# 59644           UMUC3_URINARY_TRACT
#
#                                          isomeric_smiles       auc
# 0      C1=CN(C(=O)N=C1)[C@H]2[C@@H]([C@@H]([C@H](O2)C...  0.624488
# 1      C1=CN(C(=O)N=C1)[C@H]2[C@@H]([C@@H]([C@H](O2)C...  0.964842
# 2      C1=CN(C(=O)N=C1)[C@H]2[C@@H]([C@@H]([C@H](O2)C...  1.058269
# 3      C1=CN(C(=O)N=C1)[C@H]2[C@@H]([C@@H]([C@H](O2)C...  0.774125
# 4      C1=CN(C(=O)N=C1)[C@H]2[C@@H]([C@@H]([C@H](O2)C...  1.106664
# ...                                                  ...       ...
# 59640                                    C(C(=O)O)(Cl)Cl  0.995841
# 59641                                    C(C(=O)O)(Cl)Cl  0.906113
# 59642                                    C(C(=O)O)(Cl)Cl  0.978206
# 59643                                    C(C(=O)O)(Cl)Cl  0.946825
# 59644                                    C(C(=O)O)(Cl)Cl  0.990270
#
# [59645 rows x 3 columns]
